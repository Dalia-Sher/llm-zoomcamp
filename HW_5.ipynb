# %% [markdown]
# #### Q1. Running Mage

# %% [markdown]
# v0.9.72

# %% [markdown]
# #### Q2. Reading the documents

# %%
#!pip install python-docx
# Out:
# Collecting python-docx
#   Downloading python_docx-1.1.2-py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: lxml>=3.1.0 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from python-docx) (5.3.0)
# Requirement already satisfied: typing-extensions>=4.9.0 in /home/codespace/.local/lib/python3.10/site-packages (from python-docx) (4.12.2)
# Downloading python_docx-1.1.2-py3-none-any.whl (244 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 244.3/244.3 kB 5.3 MB/s eta 0:00:0038.4 MB/s eta 0:00:01
# Installing collected packages: python-docx
# Successfully installed python-docx-1.1.2
#
# [notice] A new release of pip is available: 24.1.2 -> 24.2
# [notice] To update, run: python3 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
#!pip install docx
# Out:
# Collecting docx
#   Downloading docx-0.2.4.tar.gz (54 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.9/54.9 kB 1.4 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting lxml (from docx)
#   Downloading lxml-5.3.0-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (3.8 kB)
# Requirement already satisfied: Pillow>=2.0 in /home/codespace/.local/lib/python3.10/site-packages (from docx) (10.4.0)
# Downloading lxml-5.3.0-cp310-cp310-manylinux_2_28_x86_64.whl (5.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.0/5.0 MB 47.4 MB/s eta 0:00:000m eta 0:00:01
# Building wheels for collected packages: docx
#   Building wheel for docx (pyproject.toml) ... done
#   Created wheel for docx: filename=docx-0.2.4-py3-none-any.whl size=53896 sha256=67591a11b022d03ab4239e253474d5c0fb0a88ea0a06ca9a2eb6d75c7f07a6d6
#   Stored in directory: /home/codespace/.cache/pip/wheels/81/f5/1d/e09ba2c1907a43a4146d1189ae4733ca1a3bfe27ee39507767
# Successfully built docx
# Installing collected packages: lxml, docx
# Successfully installed docx-0.2.4 lxml-5.3.0
#
# [notice] A new release of pip is available: 24.1.2 -> 24.2
# [notice] To update, run: python3 -m pip install --upgrade pip

# %%
import io
import requests
import docx

# %%
def clean_line(line):
    line = line.strip()
    line = line.strip('\uFEFF')
    return line

def read_faq(file_id):
    url = f'https://docs.google.com/document/d/{file_id}/export?format=docx'
    
    response = requests.get(url)
    response.raise_for_status()
    
    with io.BytesIO(response.content) as f_in:
        doc = docx.Document(f_in)

    questions = []

    question_heading_style = 'heading 2'
    section_heading_style = 'heading 1'
    
    heading_id = ''
    section_title = ''
    question_title = ''
    answer_text_so_far = ''
     
    for p in doc.paragraphs:
        style = p.style.name.lower()
        p_text = clean_line(p.text)
    
        if len(p_text) == 0:
            continue
    
        if style == section_heading_style:
            section_title = p_text
            continue
    
        if style == question_heading_style:
            answer_text_so_far = answer_text_so_far.strip()
            if answer_text_so_far != '' and section_title != '' and question_title != '':
                questions.append({
                    'text': answer_text_so_far,
                    'section': section_title,
                    'question': question_title,
                })
                answer_text_so_far = ''
    
            question_title = p_text
            continue
        
        answer_text_so_far += '\n' + p_text
    
    answer_text_so_far = answer_text_so_far.strip()
    if answer_text_so_far != '' and section_title != '' and question_title != '':
        questions.append({
            'text': answer_text_so_far,
            'section': section_title,
            'question': question_title,
        })

    return questions

# %%
faq_documents = {
    'llm-zoomcamp': '1qZjwHkvP0lXHiE4zdbWyUXSVfmVGzougDD6N37bat3E',
}

# %%
documents = []

for course, file_id in faq_documents.items():
    print(course)
    course_documents = read_faq(file_id)
    documents.append({'course': course, 'documents': course_documents})
# Out:
# llm-zoomcamp

# %%
len(documents)
# Out:
# 1

# %% [markdown]
# #### Q3. Chunking

# %% [markdown]
# 87

# %% [markdown]
# #### Q4. Export

# %% [markdown]
# a976d6e7

# %% [markdown]
# #### Q5. Testing the retrieval

# %% [markdown]
# bf024675

# %% [markdown]
# #### Q6. Reindexing

# %% [markdown]
# b6fa77f3
